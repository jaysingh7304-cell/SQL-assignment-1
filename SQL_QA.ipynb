# %% [markdown]
# ### Q1. Create a New Database and Table for Employees

# %%
CREATE DATABASE company_db;
USE company_db;

CREATE TABLE employees (
  employee_id INT PRIMARY KEY,
  first_name VARCHAR(50),
  last_name VARCHAR(50),
  department VARCHAR(50),
  salary INT,
  hire_date DATE
);

# %% [markdown]
# ### Q2. Insert Data into Employees Table

# %%
INSERT INTO employees VALUES
(101,'Amit','Sharma','HR',50000,'2020-01-15'),
(102,'Riya','Kapoor','Sales',75000,'2019-03-22'),
(103,'Raj','Mehta','IT',90000,'2018-07-11'),
(104,'Neha','Verma','IT',85000,'2021-09-01'),
(105,'Arjun','Singh','Finance',60000,'2022-02-10');

# %% [markdown]
# ### Q3. Display All Employee Records Sorted by Salary

# %%
SELECT * FROM employees ORDER BY salary ASC;

# %% [markdown]
# ### Q4. Show Employees Sorted by Department and Salary

# %%
SELECT * FROM employees ORDER BY department ASC, salary DESC;

# %% [markdown]
# ### Q5. List All Employees in IT Department

# %%
SELECT * FROM employees WHERE department='IT' ORDER BY hire_date DESC;

# %% [markdown]
# ### Q6. Create and Populate Sales Table

# %%
CREATE TABLE sales (
  sale_id INT PRIMARY KEY,
  customer_name VARCHAR(50),
  amount INT,
  sale_date DATE
);

INSERT INTO sales VALUES
(1,'Aditi',1500,'2024-08-01'),
(2,'Rohan',2200,'2024-08-03'),
(3,'Aditi',3500,'2024-09-05'),
(4,'Meena',2700,'2024-09-15'),
(5,'Rohan',4500,'2024-09-25');

# %% [markdown]
# ### Q7. Display Sales Sorted by Amount

# %%
SELECT * FROM sales ORDER BY amount DESC;

# %% [markdown]
# ### Q8. Sales by Customer Aditi

# %%
SELECT * FROM sales WHERE customer_name='Aditi';

# %% [markdown]
# ### Q9. Difference Between Primary Key and Foreign Key

# %%
Primary Key uniquely identifies a record, while Foreign Key links records between tables.

# %% [markdown]
# ### Q10. What are Constraints in SQL

# %%
Constraints are rules applied to table columns to enforce data integrity.
